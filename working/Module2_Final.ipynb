# %% [markdown]
# ***Méthodes numériques: Module 2***
# ***********************************
# Space and Time: Modélisation de l'écoulement du trafic.
# ==
# ## 1. Introduction #
#
# Dans ce module nous allons résoudre une équation non-linéaire à deux variables en discrétisant à la fois dans le temps (en utilisant la forward-difference) et dans l'espace (en utilisant la backward-difference). Nous utiliserons également les nouveaux outils introduit dans ce module: sympy et lambdify, qui nous permettrons d'écrire des formules mathématiques dans nos codes et d'utiliser des fonctions de manière plus confortable.
#
# Comme dans le module 1, nous importons la librairie numpy et matplotlib pour pouvoir dessiner des graphiques, mais également sympy et lambdify.

# %%
import numpy
import sympy
from matplotlib import pyplot
# %matplotlib inline
from matplotlib import rcParams
rcParams['font.family']='serif'
rcParams['font.size']=16
from sympy import init_printing
init_printing()
from sympy.utilities.lambdify import lambdify

# %% [markdown]
# ## 2. Principe #
#
# L'équation que l'on se propose de résoudre est la suivante: $$\frac{\partial{\rho}}{\partial{t}}+\frac{\partial{F}}{\partial{x}}=0$$
#
# Cette équation modélise le flux du trafic de voitures sur l'autoroute. Il s'agit en fait de l'équation non-linéaire de convection appliquée à la densité de voiture, $\rho$. La fonction F représente le flux des voitures donné par $F=V \rho$ où V est la vitesse moyenne des voitures.
#
# On modélise le fait que la vitesse varie en fonction de la densité de voiture en exprimant que la vitesse est maximale quand la densité de voiture est nulle et qu'elle est nulle quand la densité de voiture atteind une densité critique que l'on appelle $\rho_{max}$, ce qui se traduit par la formule suivante:
#
# $$V = V_{max}(1-\frac{\rho}{\rho_{max}})$$
#
# Nous voulons discrétiser notre équation en utilisant l'approximation de la dérivée vers l'avant pour le temps et vers l'arrière pour l'espace, c'est-à-dire:
#
# $$\frac{\partial{\rho}}{\partial{t}} \cong \frac{\rho_{i}^{n+1} - \rho_{i}^{n}}{\Delta t}$$ et
# $$\frac{\partial{F}}{\partial{x}} \cong \frac{F_{i}^{n} - F_{i-1}^{n}}{\Delta x}$$
#
# ### Remarques:
# - Les exposants représentent les indices de temps (n) et les indices en dessous sont les indices pour l'espace (i).
# - $F_{i}^{n}=F(\rho_{i}^{n})$. Nous avons d'abord pensé à développer l'équation à discrétiser en exprimant tout en termes de $\rho$, mais cela augmente l'erreur que l'on fait en discrétisant et il est préférable de discrétiser F et de calculer directement sa valeur à chaque instant et point de l'espace.

# %% [markdown]
# L'équation devient: $$\frac{\rho_{i}^{n+1} - \rho_{i}^{n}}{\Delta t}=\frac{F_{i}^{n} - F_{i-1}^{n}}{\Delta x}$$
# $$\Leftrightarrow$$
#
# $$\rho_{i}^{n+1}= \rho_{i}^{n}+\frac{\Delta t}{\Delta  x}(F_{i}^{n} - F_{i-1}^{n})$$
# où à chaque étape, la seule inconnue est $\rho_{i}^{n+1}$.

# %% [markdown]
# ## 3. Code
#
# Nous commencons par créer la fonction F($\rho$) que nous pourrons ensuite réutiliser telle quelle dans le code.

# %%
rho=sympy.symbols('rho')
V_max=sympy.symbols('V_max')
rho_max=sympy.symbols('rho_max')
F=rho*V_max*(1-rho/rho_max)
flamb=lambdify((rho,V_max,rho_max),F)
F
# Out:
#        ⎛   ρ      ⎞
# Vₘₐₓ⋅ρ⋅⎜- ──── + 1⎟
#        ⎝  ρₘₐₓ    ⎠

# %% [markdown]
# Nous allons résoudre l'équation pour différents paramètres de départ. Certains paramètres, comme la longueur sur laquelle nous étudions cette équation, seront les mêmes pour tous les cas et nous les fixons donc à l'avance. Ce sont les paramètres invariants.

# %% [markdown]
# ### Paramètres invariants du problème.

# %%
L=11 #km
rhomax=250.#voitures/km
nx=51
dx=L/(nx-1)
dt=.001#heures

# %% [markdown]
# ### Fonction: Calcul de $\rho$ et $v$.
# Afin de pouvoir facilement déterminer les solutions de l'équation en partant de conditions initiales différentes, le code qui va discrétiser l'équation est mis sous forme de fonction. Elle nous donnera la densité, le flot F et la vitesse du trafic sur la portion de route considérée à partir des variables suivantes :
#
# - $\rho$(x,0) la condition initiale (=initial)
# - numberstep: le nombre de pas de temps effectués. En faisant varier ce nombre, nous pourrons choisir le temps auquel on souhaite obtenir $\rho$, $v$, et $F$.
# - $\rho$(0,t) la condition aux limites (=bound)
# - $V_{max}$ la vitesse maximale des voitures atteinte lorsque la densité du trafic est (quasi) nulle.

# %% [markdown]
# On implémente cette équation pour calculer la densité à une position n : $$\rho_{i}^{n+1}= \rho_{i}^{n}+\frac{\Delta t}{\Delta  x}(F_{i}^{n} - F_{i-1}^{n})$$
# et celle-ci pour calculer la vitesse : $V = V_{max}(1-\frac{\rho}{\rho_{max}})$

# %%
def rho(initial,numberstep,bound,vmax):
    rho00=initial.copy() #Cette copie de la densité initiale nous assure de garder "initial" inchangée par le processus.
    for n in range(1,numberstep): 
        rhocopy = rho00.copy()
        rho00[1:] = rhocopy[1:]-dt/dx*(flamb(rhocopy[1:],vmax,rhomax)-flamb(rhocopy[0:-1],vmax,rhomax))
        rho00[0] = bound
    u=numpy.array([rho00,vmax*(1-rho00/rhomax)/3.6,flamb(rho00,vmax,rhomax)])#on divise la vitesse par 3.6 car la vitesse doit être finalement exprimée en m/s
    return u

# %% [markdown]
# - $rho$ donnera donc un vecteur $\boldsymbol{u} = (\rho,v,F)$ avec $\rho,v, F$ en positions respectives 0,1 et 2.
#
# Remarque: $\rho$ est exprimé en voitures/km, v en m/s et F en voitures/heure

# %% [markdown]
# ## 4. Simulation result: Part A.

# %% [markdown]
# Tout d'abord, nous allons créer une fonction pour dessiner les graphiques de la densité, vitesse et flot de chaque situation sans devoir à chaque fois réecrire tout le code:

# %%
def graphdensity(rho,x,ymin,ymax):
    pyplot.plot(x, rho, color='#003366',ls='--', lw=1)
    pyplot.ylim(ymin,ymax);
    pyplot.xlabel('x (km)', fontsize=14) #x label
    pyplot.ylabel('rho(voitures/km)', fontsize=14) #y label
    pyplot.title('Densité de voiture en fonction de la position', y=1.08)

# %%
def graphvelo(rho,x,ymin,ymax):
    pyplot.plot(x,rho, color='#003366', ls='--', lw=1)
    pyplot.ylim(ymin,ymax);
    pyplot.xlabel('x (km)', fontsize=14) #x label
    pyplot.ylabel('v (m/s)', fontsize=14) #y label
    pyplot.title('Vitesse moyenne en fonction de la position', y=1.08, fontsize=15) ;

# %%
def graphflot(rho,x,ymin,ymax):
    pyplot.plot(x,rho, color='#003366', ls='--', lw=1)
    pyplot.ylim(ymin,ymax);
    pyplot.xlabel('x (km)', fontsize=14) #x label
    pyplot.ylabel('F (voitures/h)', fontsize=14) #y label,
    pyplot.title('Flot du trafic en fonction de la position', y=1.08, fontsize=15) ;

# %% [markdown]
# - Soit la densité initiale suivante :

# %%
x = numpy.linspace(0,L,nx)#x est défini une seule fois pour les deux simulations car il ne change pas 
rho0 = numpy.ones(nx)*10
rho0[10:20] = 50

# %% [markdown]
# - Voyons l'allure de cette densité répartie sur la portion de route :

# %%
graphdensity(rho0,x,9.0,60.0)

# %% [markdown]
# - On peut modifier le second argument ($nt$) de la fonction rho pour voir l'allure de la densité, du flot ou de la vitesse sur le segment de longueur 11km au temps $t=nt*0.001 h=nt*0.06 minutes$.

# %% [markdown]
# On crée une fonction pratique qui trouve nt à partir du temps donné en minutes :

# %%
def time(t):
    nt=int(t/0.06)+1
    return nt

# %% [markdown]
# (Nous utiliserons cette fonction plusieurs fois par la suite)

# %% [markdown]
# ###### À titre d'exemple, voyons l'allure de la densité, de la vitesse et du flot du trafic sur la portion de route après 2,5 minutes :

# %%
graphdensity(rho(rho0,time(2.5),10,80.0)[0],x,9.0,60.0)

# %%
graphvelo(rho(rho0,time(2.5),10,80.0)[1],x,15.0,30.0)

# %%
graphflot(rho(rho0,time(2.5),10,80.0)[2],x,500.0,3200.0)

# %% [markdown]
# ## 5. Simulation result: Part B.

# %% [markdown]
# - Soit une autre densité initiale :

# %%
rho1 = numpy.ones(nx)*20 
rho1[10:20] = 50

# %% [markdown]
# - Voyons l'allure de cette densité répartie sur la portion de route :

# %%
graphdensity(rho1,x,10.0,60.0)

# %% [markdown]
# ###### À nouveau, voyons l'allure de la densité, de la vitesse et du flot de trafic sur la portion de route après 2,5 minutes :

# %%
graphdensity(rho(rho1,time(2.5),20,136.0)[0],x,10.0,60.0)

# %%
graphvelo(rho(rho1,time(2.5),20,136.0)[1],x,30.0,40.0)

# %%
graphflot(rho(rho1,time(2.5),20,136.0)[2],x,2400.0,6000.0)

# %% [markdown]
# ## 6. Questions

# %% [markdown]
# Dans cette section, nous répondons aux questions posées dans l'énoncé pour chacune des deux simulations.

# %% [markdown]
# - Nous créeons deux fonctions qui donnent le vecteur vitesse au temps t exprimé en minute pour les deux simulations A et B. Cette méthode nous permet d'alléger les réponses et d'améliorer la lisibilité, elle nous semble donc intéressante. Nous utiliserons ensuite les deux fonctions numpy.min et numpy.mean qui donnent respectivement la valeur minimale et la moyenne d'une liste pour répondre aux questions.

# %%
def VA(t):
    u=rho(rho0,time(t),10,80.0)[1]
    return u

# %%
def VB(t):
    u=rho(rho1,time(t),20,136.0)[1]
    return u

# %% [markdown]
# #### PART A

# %% [markdown]
# $\underline{Note}$ : Toutes les vitesses seront données en m/s et arrondies à la deuxième décimale.

# %% [markdown]
# Initialement, la vitesse minimale est :

# %%
round(numpy.min(VA(0)),2)
# Out:
# 17.78

# %% [markdown]
# À t = 3 minutes, la vitesse moyenne est :

# %%
round(numpy.mean(VA(3)),2)
# Out:
# 20.64

# %% [markdown]
# À t = 6 minutes, la vitesse minimale est :

# %%
round(numpy.min(VA(6)),2)
# Out:
# 18.78

# %% [markdown]
# ### PART B

# %% [markdown]
# $\underline{Note}$ : Toutes les vitesses seront données en m/s et arrondies à la deuxième décimale.

# %% [markdown]
# Initialement, la vitesse minimale est :

# %%
round(numpy.min(VB(0)),2)
# Out:
# 30.22

# %% [markdown]
# À t = 3 minutes, la vitesse moyenne est :

# %%
round(numpy.mean(VB(3)),2)
# Out:
# 33.87

# %% [markdown]
# À t = 3 minutes, la vitesse minimale est :

# %%
round(numpy.min(VB(3)),2)
# Out:
# 30.99

# %% [markdown]
# ## 7. Autre approche du problème: animation visuelle.

# %% [markdown]
# Dans cette section, nous réalisons l'animation de la variation de la courbe de densité pour la partie A au cours du temps.

# %%
from matplotlib import animation
from IPython.display import HTML

# %% [markdown]
# On doit redonner la situation initiale ainsi que la vitesse intiale.

# %%
vmax=80.
u = numpy.ones(nx)*10
u[10:20] = 50
un=numpy.ones(nx)

# %% [markdown]
# On doit également donner un nombre d'étapes nt où l'animation s'arrêtera.
# ###### Estimation de nt:
# Nous voulons que l'animation s'arrête au moment où le bouchon a dépassé le tronçon de 11 km auquel on s'intéresse. Pour avoir une borne supérieure, on va supposer en première approximation que la vitesse moyenne du bouchon reste constante et calculer le temps nécessaire à ce que le bouchon parcoure les 9 km qui sépare le début du bouchon du bord droit.
#
# La vitesse moyenne initiale du bouchon est:
#
# $v=80.0km/h(1-\frac{50.0}{250.0})= 64.0 km/h$
#
# Le temps nécessaire pour parcourir 9 km à cette vitesse est:
#
# $t=\frac{9km}{64km/h}=0.141h$
# ce qui correspond à nt=141.

# %%
nt=141

# %% [markdown]
# Nous définissons le cadre dans lequel l'animation aura lieu.

# %%
fig = pyplot.figure(figsize=(8,5))
ax = pyplot.axes(xlim=(0,11), ylim=(10,60))
line = ax.plot([], [], color='#003366', ls='--', lw=3)[0]
pyplot.xlabel('x (km)', fontsize=14) #x label
pyplot.ylabel('rho (voitures/km)', fontsize=14) #y label
pyplot.title('Densité de voitures en fonction de la position', y=1.08)
pyplot.close()

# %% [markdown]
# On reconstruit la densité comme nous l'avons fait dans la fonction rho, avec la condition au bord : $\rho (0,t)=10$ :

# %%
def density(i):
    line.set_data(x,u)
    
    un = u.copy() 
    u[1:] = un[1:]-dt/dx*(flamb(un[1:],vmax,rhomax)-flamb(un[0:-1],vmax,rhomax))
    u[0] = 10

# %% [markdown]
# Dans cette animation, le paramètre 'interval' est le temps en millisecondes qui s'écoule entre deux changements du graphique (les frames). Nous voulons pouvoir raccorder le temps qui s'écoule dans notre animation par rapport au temps réel. Or notre étape de temps est de 0.001 heure= 3.6 secondes=3600 millisecondes. Ainsi, si nous prenons notre interval=360, notre animation ira 10 fois plus vite qu'en réalité.

# %%
anim = animation.FuncAnimation(fig, density,frames=nt, interval=360)

# %% [markdown]
# Voyons maintenant comment la densité évolue au cours du temps sur la portion de route considérée.

# %%
HTML(anim.to_html5_video())
# Out:
# <video width="800.0" height="500.0" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# ## 8. Interprétation physique des résultats obtenus

# %% [markdown]
# ### I. Comparaison des simulations A et B.
# Tout d'abord, nous remarquons que cette modélisation semble assez correcte puisqu'on assiste à un étalement dans l'espace du pic de densité, ce qui correspon à l'intuition que l'on se fait d'un ralentissement sur une seule voie de circulation. Cependant cela reste un medèle théorique qui ne prend pas en compte le caractère humain de la conduite des voitures et des évènements tels qu'un  accident.
# Nous remarquons également que pour les deux simulations, on obtient des courbes de même allure mais:
# - la vitesse maximale étant plus élevée dans la partie B, le graphique avance plus dans l'espace pour le même nombre d'étapes
# - le nombre de voitures en dehors du bouchon semble peut influencer l'allure générale de la courbe.
#
# Pour pouvoir mieux comprendre la façon dont le pic de densité évolue, nous allons regarder des cas de densité initiale plus complexes et également changer la longueur du tronçon sur lequel on examine notre solution.

# %% [markdown]
# ### II. Prolonger l'expérience...

# %% [markdown]
# Imaginons que le modèle s'étende à une portion de route plus grande. On souhaite examiner, avec une même répartition de densité initiale, comment la densité évolue sur une plus longue période. Quand le pic de densité correspondant au bouchon se résorbe-t-il ?

# %% [markdown]
# - Nous souhaitons garder le même pas dx selon x. voyons ce qu'il vaut :

# %%
dx
# Out:
# 0.22

# %% [markdown]
# - On veut une liste de positions qui s'étende beaucoup plus loin que 11 km. On va changer la valeur de L, en prenant soin de garder un nombre qui, divisé par dx, donne un entier (afin que le nombre de pas effectués de 0 à L soit entier).
# Prenons par exemple :

# %%
L=220 #km

# %% [markdown]
# - On doit alors créer une nouvelle liste de positions qui aille de 0 à 220 km par pas dx.

# %%
nx_bis= (L/dx)+1
x_bis = numpy.linspace(0,L,nx_bis)

nx_bis=numpy.int(nx_bis) 
#Cette dernière étape pour s'assurer que nx_bis soit un entier (important quand le nombre définit la longueur d'une liste !).

# %% [markdown]
# - Nous étendons la densité initiale. Elle sera maintenant de 10 voitures/km sur les 220 km sauf sur la portion de route ou elle vaut 50 voitures/km.

# %%
rho0 = numpy.ones(nx_bis)*10
rho0[10:20] = 50

# %%
graphdensity(rho0,x_bis,9.0,60.0)

# %% [markdown]
# - Voyons l'allure de la densité de trafic après 2.5 minutes (temps repère utilisé pour les simulations A et B):

# %%
graphdensity(rho(rho0,time(2.5),10,80.0)[0],x_bis,9.0,60.0)

# %% [markdown]
# Nous allons à présent regarder comment évolue la densité lorsqu'on regarde beaucoup plus tard, après une, deux et quatre heures

# %%
graphdensity(rho(rho0,time(60),10,80.0)[0],x_bis,9.0,60.0)

# %% [markdown]
# => Le bouchon ne s'est pas résorbé après une heure, mais la densité maximale est descendue à moins de la moitié de sa valeur initiale

# %%
graphdensity(rho(rho0,time(120),10,80.0)[0],x_bis,9.0,60.0)

# %%
graphdensity(rho(rho0,time(180),10,80.0)[0],x_bis,9.0,60.0)

# %% [markdown]
# On voit qu'après 3 heures, le pic de densité ne s'est toujours pas résorbé et sort simplement du cadre de notre simulation. Il a également beaucoup diminué.

# %% [markdown]
# ### III. D'autres conditions initiales...

# %% [markdown]
# On peut s'intéresser au cas légèrement plus compliqué de l'évolution de la densité à partir d'une densité initiale différente.
# On va ajouter un pic de densité à la densité rho0 et observer comment les deux bouchons interfèrent au cours du temps.

# %%
rho0_bis = numpy.ones(nx_bis)*10
rho0_bis[10:20] = 50
rho0_bis[50:70] = 40 
# Ajout d'un pic à 40 voitures/km sur une distance deux fois plus grande que celle couverte par le premier bouchon

# %%
graphdensity(rho0_bis,x_bis,9.0,60.0)

# %% [markdown]
# - Voyons l'allure de la densité de trafic après 1 heure :

# %%
graphdensity(rho(rho0_bis,time(60),10,80.0)[0],x_bis,9.0,60.)

# %% [markdown]
# On voit que les deux pics de densité commencent à se recouvrir l'un l'autre.

# %% [markdown]
# - Voyons l'allure de la densité de trafic après 2, puis 3 heures :

# %%
graphdensity(rho(rho0_bis,time(120),10,80.0)[0],x_bis,9.0,60.0)

# %% [markdown]
# On observe ici quelque chose de très intéressant: après un certain temps, le double pic de densité se réduit en un pic unique.

# %%
graphdensity(rho(rho0_bis,time(150),10,80.0)[0],x_bis,9.0,60.0)

# %% [markdown]
# => En ajoutant un bouchon dans les conditions initiales, on a causé une perturbation globale du trafic importante qui se résorbe moins rapidement.

# %% [markdown]
# Nous allons à présent nous intéresser à une situation limite: lorsque la densité du pic de densité de départ est proche de la densité limite.

# %%
x = numpy.linspace(0,L,nx)
rho2 = numpy.ones(nx)*10
rho2[10:20] = 150

# %%
graphdensity(rho2,x,0.0,250)

# %%
graphdensity(rho(rho2,time(5),10,80.0)[0],x,0.0,300.0)

# %% [markdown]
# On voit qu'on a une différence dans la façon dont se disperse le pic quand on augmente le rapport entre le rho du pic et rhomax.

# %% [markdown]
# ## 9. Conclusion générale

# %% [markdown]
# Nous avons considéré des cas simples de modélisation du trafic. En pratique, les densités initiales sont évidemment plus complexes, mais nous avons pu, à partir des cas étudiés, nous rendre compte de l'allure de la propagation de la densité de trafic (et de la propagation d'un bouchon correspondant à la densité autour d'un pic de densité).
# Grâce aux deux sections précédentes, nous pouvons nous rendre compte de l'importance qu'un pic de densité peut avoir de par le fait qu'il ne se résorbe pas rapidement sans phénomène extérieur à ceux étudiés dans ce modèle.
